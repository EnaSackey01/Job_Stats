# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import ks_2samp
from scipy.stats import kstest, norm


Cleaned_Job_df = pd.read_csv("Joined_Data/Cleaned_New_Joined_Data.csv")

Cleaned_Job_df['salary_standardized'] = Cleaned_Job_df['salary_standardized'].str.replace('\d{2}:\d{2}.\d{1}', '', regex=True)
Cleaned_Job_df = Cleaned_Job_df[Cleaned_Job_df['salary_standardized'] != '']

Cleaned_Job_df['salary_standardized']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [56], line 6
#       4 from scipy.stats import ks_2samp
#       5 from scipy.stats import kstest, norm
# ----> 6 from transform import jobs_df
#       8 Cleaned_Job_df = pd.read_csv("Joined_Data/Cleaned_New_Joined_Data.csv")
#      10 Cleaned_Job_df['salary_standardized'] = Cleaned_Job_df['salary_standardized'].str.replace('\d{2}:\d{2}.\d{1}', '', regex=True)
#
# ImportError: cannot import name 'jobs_df' from 'transform' (/Users/esackeyfio_ifds/Job_Stats/transform.py)

# %%
Cleaned_Job_df.shape
# Out:
# (2229, 136)

# %%
# All data analyst salaries

#sns.histplot(data = Cleaned_Job_df, x = 'salary_standardized', kde = True).set(title = 'Full Salaries of All Data Analysts')
sns.histplot(Cleaned_Job_df["salary_standardized"], kde=True)

plt.savefig("Images/full_salary_hist.jpg")

# %%
# Histograms salary_standardized

salary_standardized = Cleaned_Job_df["salary_standardized"]

salary_standardized.hist()

plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.title("Histogram of Standard Salaries")

plt.savefig("Images/Histogram of Standard Salaries.jpg")
